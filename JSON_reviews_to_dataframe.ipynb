# %% [markdown]
# <a href="https://colab.research.google.com/github/Anna-Mens/Graded-Assisgnment/blob/main/JSON_reviews_to_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import pandas as pd

# %%
file_path = '/content/data_10.json'
with open(file_path, 'r') as file:
    data = json.load(file)

# %%
reviews_data = []
count = 0
for result in data['results']:
  asin = result['content']["asin"]
  for review in result['content']['reviews']:
    count += 1
    try:
      review_info = {
      'review_id': review['id'],
      'product_id': asin,
      "title": review["title"],
      "author": review["author"],
      "rating": review["rating"],
      "content": review["content"],
      "timestamp": review["timestamp"],
      "profile_id": review["profile_id"],
      "is_verified": review["is_verified"],
      "helpful_count": review.get('helpful_count', 0),
      "product_attributes": review["product_attributes"]
      }
      reviews_data.append(review_info)
    except:
      print(count)
      break

reviews_df = pd.DataFrame(reviews_data)
reviews_df.to_csv('reviews_10.csv', index=False)
reviews_df.head(100)
# Out:
#          review_id  product_id  \
# 0    RVUGJDBJ0N8AM  B08TMTFR6B
# 1    RFGIHG0A3VEHP  B08TMTFR6B
# 2   R1X236GWTX9QEO  B08TMTFR6B
# 3    R1OUNLDVBE1CZ  B08TMTFR6B
# 4   R2DSLUCDF92EVF  B08TMTFR6B
# ..             ...         ...
# 95  R1RRRNQRKRNS9T  B08TMTFR6B
# 96  R20Q2GRI4IBYDS  B08TMTFR6B
# 97  R19VQV48JG5VXS  B08TMTFR6B
# 98  R1KHVY9C9858C4  B08TMTFR6B
# 99  R2SRO6TZFL5UYC  B08TMTFR6B
#
#                                                 title           author  \
# 0                    5.0 out of 5 stars Great headset               BW
# 1                    5.0 out of 5 stars Great product  Amazon Customer
# 2         5.0 out of 5 stars Really nice headphones!!             Lexi
# 3       4.0 out of 5 stars Light and very comfortable              Sam
# 4                 5.0 out of 5 stars Great headphones          Jami L.
# ..                                                ...              ...
# 95              4.0 out of 5 stars Good for the money  Amazon Customer
# 96  4.0 out of 5 stars Amazing sound and impressiv...            Karen
# 97                    5.0 out of 5 stars I LOVE THESE           Nicole
# 98                     4.0 out of 5 stars I like them       j. azerina
# 99             5.0 out of 5 stars Worth every dollar.             Shly
#
#     rating                                            content  \
# 0        5  VERY comfortable and great sound. I love the n...
# 1        5  These have excellent sound quality. Comfortabl...
# 2        5  Durability: 10/10Buttons: 9/10Battery Life: 8/...
# 3        4  These are very lightweight and comfortable hea...
# 4        5  I bought these for my granddaughter who is 17....
# ..     ...                                                ...
# 95       4  I been having problems with headphone because ...
# 96       4  I bought these headphones especially for the g...
# 97       5  I love the 3 different modes. I have been usin...
# 98       4  They sound nice, they look nice, the earphones...
# 99       5  I bought these to be ready for a trip. Didn't ...
#
#                                            timestamp  \
# 0        Reviewed in the United States July 29, 2024
# 1       Reviewed in the United States August 9, 2024
# 2      Reviewed in the United States August 25, 2024
# 3         Reviewed in the United States July 3, 2024
# 4    Reviewed in the United States September 9, 2024
# ..                                               ...
# 95    Reviewed in the United States January 30, 2024
# 96    Reviewed in the United States January 29, 2024
# 97        Reviewed in the United States May 24, 2024
# 98  Reviewed in the United States September 11, 2023
# 99         Reviewed in the United States May 8, 2024
#
#                       profile_id  is_verified  helpful_count  \
# 0   AG3TPEUXB3FFZ6WYTLTGEEDIBDLA         True              8
# 1   AGFII6N3YUQFXRUXRUYFK2H5GBGQ         True              1
# 2   AFMPAN6BHRJZL36QCKZL54EBWYFA         True              5
# 3   AF723YX3ZB6ACM45L5SUIDJNGSHA         True             14
# 4   AHSKVRJTTIUSSXXG4JLNRQOWUODA         True              0
# ..                           ...          ...            ...
# 95  AHCJ7O73ZDOKVE2ZIERLCP7M7YKA         True              0
# 96  AFCDMRISSSLW7UJTWUWWXLYYHMVQ         True              0
# 97  AHDUPA7TGDAPYKPK6QCBIB34XEUA         True              0
# 98  AGUO6FZ7VJ6LZCDKZMSTY25KKE5A         True             16
# 99  AHIRHLMMMHYTMWPSNSJPM63Q65DQ         True              0
#
#    product_attributes
# 0    Color: Rose Gold
# 1        Color: Black
# 2        Color: Black
# 3        Color: White
# 4        Color: White
# ..                ...
# 95       Color: Black
# 96       Color: White
# 97       Color: Black
# 98   Color: Rose Gold
# 99       Color: Black
#
# [100 rows x 11 columns]

# %%
len(reviews_df)
# Out:
# 100

# %%
df_1 = pd.read_csv('/content/reviews_1.csv')
df_2 = pd.read_csv('/content/reviews_2.csv')
df_3 = pd.read_csv('/content/reviews_3.csv')
df_4 = pd.read_csv('/content/reviews_4.csv')
df_5 = pd.read_csv('/content/reviews_5.csv')
df_6 = pd.read_csv('/content/reviews_6.csv')
df_7 = pd.read_csv('/content/reviews_7.csv')
df_8 = pd.read_csv('/content/reviews_8.csv')
df_9 = pd.read_csv('/content/reviews_9.csv')
df_10 = pd.read_csv('/content/reviews_10.csv')

df_2.head()
# Out:
#         review_id  product_id  \
# 0  R381U8GJDBMZ3C  B0BXYCS74H
# 1  R192YSRYLAMSIU  B0BXYCS74H
# 2  R1JS47AJOJKY1K  B0BXYCS74H
# 3  R10098H37FA770  B0BXYCS74H
# 4  R24D3SH6D62K0P  B0BXYCS74H
#
#                                                title           author  rating  \
# 0   5.0 out of 5 stars Good: sound, battery, storage  originalmike007       5
# 1  5.0 out of 5 stars Amazing Sound and Unmatched...        Nhan Tran       5
# 2    5.0 out of 5 stars Overall the XM5 are the best          Scooley       5
# 3       5.0 out of 5 stars Are you Older? READ THIS.         Waydavis       5
# 4  4.0 out of 5 stars Got these for Grad school. ...      Expat_Medic       4
#
#                                              content  \
# 0  These sound great both for music and phone cal...
# 1  I recently upgraded to the Sony WH-1000XM5, an...
# 2  For some reason I’m obsessed with headphones s...
# 3  I am almost 65 years old SO, I DO NOT have the...
# 4  What I Like:-Very good sound quality (providin...
#
#                                        timestamp  \
# 0    Reviewed in the United States July 20, 2024
# 1  Reviewed in the United States August 11, 2024
# 2     Reviewed in the United States June 1, 2024
# 3      Reviewed in the United States May 4, 2023
# 4  Reviewed in the United States August 29, 2024
#
#                      profile_id  is_verified  helpful_count  \
# 0  AEXEJKL5NLHAWQDXD6VKERFF7Y6A         True             11
# 1  AFHWA4T4TQBLUQWBJGFHZIH3ATYQ         True              5
# 2  AHRRPRN7Y4X3UP2Z3YN6EWQJCUVQ         True             27
# 3  AFXILNJYGCIM3OBH4UNBTQTZVR2A         True            874
# 4  AHIGMCV3ATOA5CDR6FJHGX7UI3HA         True              1
#
#                                   product_attributes
# 0        Color: BlackSize: One SizeStyle: Headphones
# 1        Color: BlackSize: One SizeStyle: Headphones
# 2  Color: Midnight BlueSize: One SizeStyle: Headp...
# 3        Color: BlackSize: One SizeStyle: Headphones
# 4       Color: SilverSize: One SizeStyle: Headphones

# %%
merged_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10], ignore_index=True)
merged_df
# Out:
#           review_id  product_id  \
# 0    R1M1ZIK6WZ8AIK  B0C8PR4W22
# 1    R29N1QVFQBP9CB  B0C8PR4W22
# 2    R1MZVYL3ULXVYC  B0C8PR4W22
# 3    R2R9QWZE1V5Z41  B0C8PR4W22
# 4    R3GUSGB4IDV501  B0C8PR4W22
# ..              ...         ...
# 995  R1RRRNQRKRNS9T  B08TMTFR6B
# 996  R20Q2GRI4IBYDS  B08TMTFR6B
# 997  R19VQV48JG5VXS  B08TMTFR6B
# 998  R1KHVY9C9858C4  B08TMTFR6B
# 999  R2SRO6TZFL5UYC  B08TMTFR6B
#
#                                                  title             author  \
# 0    5.0 out of 5 stars Excellent Low cost AirPods ...             Mahajo
# 1            5.0 out of 5 stars Amazing sound quality!            Brianna
# 2    5.0 out of 5 stars The King is back, for a nic...         Apple nerd
# 3    5.0 out of 5 stars Sonic Excellence: Beats Stu...  Wehash Technology
# 4                 4.0 out of 5 stars Great Headphones!               celi
# ..                                                 ...                ...
# 995              4.0 out of 5 stars Good for the money    Amazon Customer
# 996  4.0 out of 5 stars Amazing sound and impressiv...              Karen
# 997                    5.0 out of 5 stars I LOVE THESE             Nicole
# 998                     4.0 out of 5 stars I like them         j. azerina
# 999             5.0 out of 5 stars Worth every dollar.               Shly
#
#      rating                                            content  \
# 0         5  My earliest forays into a More expensive headp...
# 1         5  Absolutely amazing! I had these in my cart for...
# 2         5  I loved my Beats Solo headphones as a teenager...
# 3         5  Immerse yourself in a world of unparalleled au...
# 4         4  Pros:- Lovely color (sandstone).- Fits comfort...
# ..      ...                                                ...
# 995       4  I been having problems with headphone because ...
# 996       4  I bought these headphones especially for the g...
# 997       5  I love the 3 different modes. I have been usin...
# 998       4  They sound nice, they look nice, the earphones...
# 999       5  I bought these to be ready for a trip. Didn't ...
#
#                                             timestamp  \
# 0    Reviewed in the United States September 11, 2023
# 1    Reviewed in the United States September 12, 2024
# 2     Reviewed in the United States September 7, 2023
# 3         Reviewed in the United States July 22, 2024
# 4         Reviewed in the United States July 22, 2024
# ..                                                ...
# 995    Reviewed in the United States January 30, 2024
# 996    Reviewed in the United States January 29, 2024
# 997        Reviewed in the United States May 24, 2024
# 998  Reviewed in the United States September 11, 2023
# 999         Reviewed in the United States May 8, 2024
#
#                        profile_id  is_verified  helpful_count  \
# 0    AGUIQ5S5JSDEN4XKQGG5JPZZQNHQ         True            453
# 1    AHBFPUIH44OKP2MY2UPXYVMQX4BQ         True              1
# 2    AEUHSKBV2ADJTTXVB55RN7UQQZTA         True            478
# 3    AGNFPNLEVHI6AF2OA3TFEV52YZ5Q         True              7
# 4    AFRRVTXY3LHOL5AJIPCUWW7QEJAQ         True             11
# ..                            ...          ...            ...
# 995  AHCJ7O73ZDOKVE2ZIERLCP7M7YKA         True              0
# 996  AFCDMRISSSLW7UJTWUWWXLYYHMVQ         True              0
# 997  AHDUPA7TGDAPYKPK6QCBIB34XEUA         True              0
# 998  AGUO6FZ7VJ6LZCDKZMSTY25KKE5A         True             16
# 999  AHIRHLMMMHYTMWPSNSJPM63Q65DQ         True              0
#
#                                     product_attributes
# 0    Color: SandstoneStyle: Studio ProSet: Without ...
# 1    Color: EarthStyle: Studio ProSet: With AppleCa...
# 2    Color: BlackStyle: Studio ProSet: Without Appl...
# 3    Color: SandstoneStyle: Studio ProSet: Without ...
# 4    Color: SandstoneStyle: Studio ProSet: Without ...
# ..                                                 ...
# 995                                       Color: Black
# 996                                       Color: White
# 997                                       Color: Black
# 998                                   Color: Rose Gold
# 999                                       Color: Black
#
# [1000 rows x 11 columns]

# %%
merged_df.to_csv('merged_data.csv', index=False)
